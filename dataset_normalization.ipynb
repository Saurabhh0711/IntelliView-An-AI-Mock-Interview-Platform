# %%
import pandas as pd
import string
import re
import numpy as np

# %%
df = pd.read_csv('data/Dataset - Dataset.csv')

# %%
df = df.fillna(value=np.nan)

# %%
df
# Out:
#                                              Questions  \
# 0    What is data science, and how does it differ f...
# 1    What are the key steps in the data science pro...
# 2         How do you handle missing data in a dataset?
# 3    Explain the bias-variance tradeoff in machine ...
# 4    Explain the difference between supervised and ...
# ..                                                 ...
# 96   What is the significance of the Mahalanobis di...
# 97   How does the Huber loss function differ from o...
# 98   What role does feature importance play in mach...
# 99   What is the purpose of using Wasserstein dista...
# 100  Explain the concept of Manifold Learning, and ...
#
#                                                Answers  Unnamed: 2 Unnamed: 3
# 0    Data science is an interdisciplinary field tha...         NaN        NaN
# 1    The data science process typically involves da...         NaN        NaN
# ...

# %%
df =  df.drop('Unnamed: 2', axis=1)
df =  df.drop('Unnamed: 3', axis=1)

# %%
df.fillna(value='None', inplace=True)

# %%
df = df.dropna()

# %%
df.head(20)
# Out:
#                                             Questions  \
# 0   What is data science, and how does it differ f...
# 1   What are the key steps in the data science pro...
# 2        How do you handle missing data in a dataset?
# 3   Explain the bias-variance tradeoff in machine ...
# 4   Explain the difference between supervised and ...
# 5   What is overfitting, and how can it be prevent...
# 6   What is the purpose of exploratory data analys...
# 7   How does feature scaling impact machine learni...
# 8   What is a confusion matrix, and how is it used...
# 9   How can feature importance be determined in a ...
# 10  What is cross-validation, and why is it import...
# 11  Explain the concept of regularization in linea...
# 12  What is the purpose of hyperparameter tuning i...
# 13  How does dimensionality reduction contribute t...
# 14  What are outliers, and how do they impact stat...
# 15  What is the role of a decision tree in machine...
# ...

# %%
df['Answers'] = df['Answers'].fillna('').astype(str)
df['Answers'] = df['Answers'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['Answers'] = df['Answers'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
df['Answers'] = df['Answers'].apply(lambda x: x.lower())
df['Answers'] = df['Answers'].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

df['Questions'] = df['Questions'].fillna('').astype(str)
df['Questions'] = df['Questions'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['Questions'] = df['Questions'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
df['Questions'] = df['Questions'].apply(lambda x: x.lower())
df['Questions'] = df['Questions'].apply(lambda x: re.sub(r'\s+', ' ', x).strip())

# %%
df
# Out:
#                                              Questions  \
# 0    what is data science and how does it differ fr...
# 1    what are the key steps in the data science pro...
# 2          how do you handle missing data in a dataset
# 3    explain the biasvariance tradeoff in machine l...
# 4    explain the difference between supervised and ...
# ..                                                 ...
# 96   what is the significance of the mahalanobis di...
# 97   how does the huber loss function differ from o...
# 98   what role does feature importance play in mach...
# 99   what is the purpose of using wasserstein dista...
# 100  explain the concept of manifold learning and h...
#
#                                                Answers
# 0    data science is an interdisciplinary field tha...
# 1    the data science process typically involves da...
# 2    missing data can be addressed by imputation te...
# 3    the biasvariance tradeoff represents the balan...
# ...

# %%
df.head(20)
# Out:
#                                             Questions  \
# 0   what is data science and how does it differ fr...
# 1   what are the key steps in the data science pro...
# 2         how do you handle missing data in a dataset
# 3   explain the biasvariance tradeoff in machine l...
# 4   explain the difference between supervised and ...
# 5   what is overfitting and how can it be prevente...
# 6   what is the purpose of exploratory data analys...
# 7   how does feature scaling impact machine learni...
# 8   what is a confusion matrix and how is it used ...
# 9   how can feature importance be determined in a ...
# 10  what is crossvalidation and why is it importan...
# 11  explain the concept of regularization in linea...
# 12  what is the purpose of hyperparameter tuning i...
# 13  how does dimensionality reduction contribute t...
# 14  what are outliers and how do they impact stati...
# 15  what is the role of a decision tree in machine...
# ...

# %%
df.to_csv('data/normalized_dataset_ds.csv', index=False)
